# %%
{'b1_phase_min': -360.0,
 'b1_phase_max': 0.0,
 'b2_phase_min': 0.0,
 'b2_phase_max': 360.0,
 'b1_phase_center': -180.0,
 'b2_phase_center': 180.0,
 'syn_p_charge': 1,
 'syn_p_mass': 48373.5894298,
 'syn_p_phi': 0.0,
 'syn_p_energy': 0.52,
 'b1_charge': (1,),
 'b2_charge': (-1,),
 'b1_path': 'C:\\Users\\wangh\\Desktop\\test_page_2b\\OutputFile\\generate_2beam\\2beam_first.dst',
 'b2_path': 'C:\\Users\\wangh\\Desktop\\test_page_2b\\OutputFile\\generate_2beam\\2beam_second.dst',
 '2beam_mode': (0, 0)}
