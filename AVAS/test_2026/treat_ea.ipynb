# %%
import h5py

h5_path = r"C:\Users\shliu\Desktop\eatest\EA_CAFe_MEBT2\002analysis\data_dir\InputData.h5"

with h5py.File(h5_path, "r") as f:
    round_name = list(f.keys())[0]
    group = f[round_name]
    print(group.keys())
    print(group["input_A"][()])
# Out:
# <KeysViewHDF5 ['input_A', 'input_Au_0', 'input_Au_1', 'input_Au_2', 'input_Au_3', 'input_Au_4', 'input_Au_5', 'input_Au_6', 'input_Au_7', 'input_B', 'input_Bu_0', 'input_Bu_1', 'input_Bu_2', 'input_Bu_3', 'input_Bu_4', 'input_Bu_5', 'input_Bu_6', 'input_Bu_7']>
# [[ 0.0488135   0.21518937  0.02355163  0.01028647 -0.0763452   0.02917882
#   -0.06241279  0.391773    0.10626368 -0.02671324  0.29172504  0.00577898
#    0.06804456  0.42559664 -0.09831129 -0.09462299 -0.10995784  0.33261985
#    0.27815675  0.37001215  0.10969124  0.06856209 -0.00882828  0.28052918
#   -0.38172557  0.13992102 -0.08173741  0.10191061  0.00500727 -0.08533806
#   -0.23544439  0.27423369 -0.0100496   0.01568391 -0.11028525  0.1176355
#    0.11209572  0.116934    0.10169957  0.04167014 -0.03219842 -0.06296805
#    0.1976312  -0.43977453  0.03822012  0.03910732 -0.06637543 -0.3710737 ]
#  [-0.18457165 -0.13628923  0.01608791 -0.0140715   0.48837384 -0.07959104
# ...

# %%
import numpy as np

h5_path = r"C:\Users\shliu\Desktop\eatest\EA_CAFe_MEBT2\002analysis\data_dir\InputData.h5"

new_data = np.array([[1, 2, 3],
                     [4, 5, 6]])

with h5py.File(h5_path, "a") as f:
    round_name = list(f.keys())[0]
    group = f[round_name]

    group.create_dataset("input_test", data=new_data)

    print(list(group.keys()))

grp = inputdata_file.create_group(round_name)

# %%
import h5py

h5_path = r"C:\Users\shliu\Desktop\eatest\EA_CAFe_MEBT2\001analysis\data_dir\OutData.h5"

with h5py.File(h5_path, "r") as f:
    round_name = list(f.keys())
    print(round_name)
    for i in round_name:
        print(i, f[i].keys())
    # round_name = list(f.keys())[0]
    # group = f[round_name]
    # print(group.keys())
    # print(group["input_A"][()])
# Out:
# ['round_0']
# round_0 <KeysViewHDF5 ['input_A', 'input_Au_0', 'input_Au_1', 'input_Au_2', 'input_Au_3', 'input_Au_4', 'input_Au_5', 'input_Au_6', 'input_Au_7', 'input_B', 'input_Bu_0', 'input_Bu_1', 'input_Bu_2', 'input_Bu_3', 'input_Bu_4', 'input_Bu_5', 'input_Bu_6', 'input_Bu_7']>
